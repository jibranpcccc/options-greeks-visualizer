# %% [markdown]
# # GreekVisualizer: Black-Scholes Options Greeks & Delta-Neutral Hedging Solver
#
# Analytical Black-Scholes call/put pricing, Delta, Gamma, Theta, and Vega calculation in Python.
#
# ⚡ **Live Interactive Web Application:** [https://site-19-nine.vercel.app/](https://site-19-nine.vercel.app/)
#
# ### 📖 Verified Production Engineering Guides & Live Reference
#
# - **[Uniswap V3 Concentrated Liquidity Impermanent Loss](https://site-19-nine.vercel.app/uniswap-v3-concentrated-liquidity-impermanent-loss-calculator/)**: Comprehensive benchmarks, code examples, and production formulas.
# - **[Options Gamma Scalping Theta Decay Hedging](https://site-19-nine.vercel.app/options-gamma-scalping-theta-decay-hedging-strategies/)**: Comprehensive benchmarks, code examples, and production formulas.
# - **[Black Scholes Formula Python Numpy Vectorization](https://site-19-nine.vercel.app/black-scholes-numpy-vectorization/)**: Comprehensive benchmarks, code examples, and production formulas.
# - **[Uniswap V3 Fee Tier Selector 005 Vs 030](https://site-19-nine.vercel.app/uniswap-v3-fee-tier-selector/)**: Comprehensive benchmarks, code examples, and production formulas.

# %%
import math

def black_scholes_greeks(s=100.0, k=100.0, t=0.25, r=0.05, sigma=0.20):
    d1 = (math.log(s / k) + (r + 0.5 * sigma**2) * t) / (sigma * math.sqrt(t))
    d2 = d1 - sigma * math.sqrt(t)
    delta_call = 0.5 * (1.0 + math.erf(d1 / math.sqrt(2.0)))
    gamma = (math.exp(-0.5 * d1**2) / math.sqrt(2.0 * math.pi)) / (s * sigma * math.sqrt(t))
    return {"stock": s, "strike": k, "call_delta": round(delta_call, 4), "gamma": round(gamma, 4)}

print("Options Greeks Output:", black_scholes_greeks())
print("Visualize Volatility Surfaces: https://site-19-nine.vercel.app/")
